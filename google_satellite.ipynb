# %%
import os.path as osp
import numpy as np
import static_map as GoogleStaticMap

# %%
store_dir = "./"
# store key in a file for security and to prevent accidental charges (not added to repo)
api_key = GoogleStaticMap.APIFile(osp.join(store_dir, "api_key.npy"))

gmap = GoogleStaticMap.GoogleStaticMap(api_key, zoom=17, size="1024x1024", 
                                       maptype="satellite", mode="RGB")

# %%
gmap.zoom(15).read(-33.867886, -63.987000).rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x112154E90>

# %%
gmap.zoom(15).save(-33.867886, -63.987000, "./")
